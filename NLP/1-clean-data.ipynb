# %%
import pandas as pd

# %%
email_df = pd.read_csv('dataset/enron_emails.csv')

# %%
email_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517401 entries, 0 to 517400
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   file        517401 non-null  object
#  1   date        517401 non-null  object
#  2   subject     498214 non-null  object
#  3   from        517401 non-null  object
#  4   to          517401 non-null  object
#  5   email_body  460390 non-null  object
# dtypes: object(6)
# memory usage: 23.7+ MB

# %%
email_df.describe()
# Out:
#                               file                                   date  \
# count                       517401                                 517401
# unique                      517401                                 224128
# top     allen___p__all_documents_1  Wed, 27 Jun 2001 16:02:00 -0700 (PDT)
# freq                             1                                   1118
#
#        subject                from      to email_body
# count   498214              517401  517401     460390
# unique  159236               20328   58564     199249
# top        RE:  kay.mann@enron.com    None        fyi
# freq      6477               16735   21847       5397

# %%
email_df.head()
# Out:
#                            file                                   date  \
# 0    allen___p__all_documents_1  Wed, 13 Dec 2000 18:41:00 -0800 (PST)
# 1   allen___p__all_documents_10  Wed, 13 Dec 2000 08:35:00 -0800 (PST)
# 2  allen___p__all_documents_100   Mon, 9 Oct 2000 07:16:00 -0700 (PDT)
# 3  allen___p__all_documents_101   Mon, 9 Oct 2000 07:00:00 -0700 (PDT)
# 4  allen___p__all_documents_102   Thu, 5 Oct 2000 06:26:00 -0700 (PDT)
#
#                                              subject  \
# 0  December 14, 2000 - Bear Stearns' predictions ...
# 1                       Bloomberg Power Lines Report
# 2        Consolidated positions: Issues & To Do list
# 3        Consolidated positions: Issues & To Do list
# 4                                                NaN
#
#                                       from                        to  \
# 0  1.11913372.-2@multexinvestornetwork.com          pallen@enron.com
# 1              messenger@ecm.bloomberg.com                      None
# ...

# %%
# email body not null
email_df_ebnn = email_df.dropna(subset=['from', 'email_body'], inplace=False)

# %%
email_df_ebnn.head()
# Out:
#                            file                                   date  \
# 0    allen___p__all_documents_1  Wed, 13 Dec 2000 18:41:00 -0800 (PST)
# 1   allen___p__all_documents_10  Wed, 13 Dec 2000 08:35:00 -0800 (PST)
# 4  allen___p__all_documents_102   Thu, 5 Oct 2000 06:26:00 -0700 (PDT)
# 5  allen___p__all_documents_103   Thu, 5 Oct 2000 05:55:00 -0700 (PDT)
# 9  allen___p__all_documents_107   Tue, 3 Oct 2000 09:13:00 -0700 (PDT)
#
#                                              subject  \
# 0  December 14, 2000 - Bear Stearns' predictions ...
# 1                       Bloomberg Power Lines Report
# 4                                                NaN
# 5                               Re: 2001 Margin Plan
# 9                                                NaN
#
#                                       from                        to  \
# 0  1.11913372.-2@multexinvestornetwork.com          pallen@enron.com
# 1              messenger@ecm.bloomberg.com                      None
# ...

# %%
email_df_ebnn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 460390 entries, 0 to 517400
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   file        460390 non-null  object
#  1   date        460390 non-null  object
#  2   subject     443042 non-null  object
#  3   from        460390 non-null  object
#  4   to          460390 non-null  object
#  5   email_body  460390 non-null  object
# dtypes: object(6)
# memory usage: 24.6+ MB

# %%
# email body unique
email_df_ebu = email_df_ebnn.drop_duplicates(subset=['email_body'], keep='last', inplace=False)

# %%
email_df_ebu.head()
# Out:
#                              file                                   date  \
# 62   allen___p__all_documents_157  Mon, 31 Dec 1979 16:00:00 -0800 (PST)
# 113  allen___p__all_documents_202  Mon, 31 Dec 1979 16:00:00 -0800 (PST)
# 240  allen___p__all_documents_319  Mon, 31 Dec 1979 16:00:00 -0800 (PST)
# 391  allen___p__all_documents_456  Mon, 19 Mar 2001 01:25:00 -0800 (PST)
# 594  allen___p__all_documents_756  Mon, 31 Dec 1979 16:00:00 -0800 (PST)
#
#                                                subject  \
# 62                                    Re: (No Subject)
# 113                                  Re: MISSION SOUTH
# 240                                                Re:
# 391                                 Re: Denver trading
# 594  Re: Carlsbad/El Paso: Aug 23 Update: Press Con...
#
#                         from                          to  \
# 62   phillip.allen@enron.com  muller@thedoghousemail.com
# 113  phillip.allen@enron.com         jsmith@austintx.com
# ...

# %%
email_df_ebu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199249 entries, 62 to 517400
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   file        199249 non-null  object
#  1   date        199249 non-null  object
#  2   subject     191914 non-null  object
#  3   from        199249 non-null  object
#  4   to          199249 non-null  object
#  5   email_body  199249 non-null  object
# dtypes: object(6)
# memory usage: 10.6+ MB

# %%
email_df_ebu.describe()
# Out:
#                                 file                                   date  \
# count                         199249                                 199249
# unique                        199249                                 179607
# top     allen___p__all_documents_157  Wed, 27 Jun 2001 16:02:00 -0700 (PDT)
# freq                               1                                    649
#
#        subject                     from      to  \
# count   191914                   199249  199249
# unique  133580                    19107   51391
# top        RE:  jeff.dasovich@enron.com    None
# freq      4712                     4380    6940
#
#                                                email_body
# count                                              199249
# unique                                             199249
# top     how is your racing going what category are you...
# freq                                                    1

# %%
# email_df_ebu.to_csv('dataset/clean_enron_emails.csv', index=False)

# %%
# len(all_receivers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# w:\Documents\CPEN\L400S1\AI\project\part3\1-clean-data.ipynb Cell 14' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/w%3A/Documents/CPEN/L400S1/AI/project/part3/1-clean-data.ipynb#ch0000017?line=0'>1</a> len(all_receivers)
#
# NameError: name 'all_receivers' is not defined
